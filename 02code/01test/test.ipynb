# %% [markdown]
# ## tit
# #### tit
#
# **bold** reguler
#
# - data
# - data
#   - data
#   - data
#
# 1. 데이터 불러오기
# 1. 모델학습
# 1. 결과평가
#
#
# `print("hell")`
#
# ```
# df=pd.read_csv("test.csv)
# ```
#
# |col|note|
# |---|----|
# |   |val|
#
# [google](http://www.google.com)
#
#
# |[이미지](경로)
#
# ----
#
# - [ ] 할 일 1
# - [ ] 할 일 2
# - [x] 완료한 일

# %%
print("test")
# Out:
# test
