# %% [markdown]
# ##### 함수
# - def name(): //함수생성
# - name() //함수호출

# %%
import random

def rand_add():
    a = random.randint(1,100)
    b = random.randint(1,100)
    answer = int(input(f'{a} + {b} = '))
    if answer == a+b:
        print("o")
    else:
        print("x")


rand_add()
# Out:
# x
