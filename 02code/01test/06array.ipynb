# %%
import numpy as np

arr1 = np.array([1, 2, 3, 4, 5])
print(arr1)
# Out:
# [1 2 3 4 5]

# %%
print(type(arr1))
# Out:
# <class 'numpy.ndarray'>

# %%
arr2 = np.array([1,2,3,4,5])
print(arr1[1])
print(arr1[1:4])
# Out:
# 2
# [2 3 4]

# %%
arr4 = np.array([1,2,3,4,5,6])
arr5 = arr4.reshape(1,6)
print(arr5)
# Out:
# [[1 2 3 4 5 6]]
