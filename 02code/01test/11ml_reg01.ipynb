# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
perch_length = np.array(
    [8.4, 13.7, 15.0, 16.2, 17.4, 18.0, 18.7, 19.0, 19.6, 20.0,
     21.0, 21.0, 21.0, 21.3, 22.0, 22.0, 22.0, 22.0, 22.0, 22.5,
     22.5, 22.7, 23.0, 23.5, 24.0, 24.0, 24.6, 25.0, 25.6, 26.5,
     27.3, 27.5, 27.5, 27.5, 28.0, 28.7, 30.0, 32.8, 34.5, 35.0,
     36.5, 36.0, 37.0, 37.0, 39.0, 39.0, 39.0, 40.0, 40.0, 40.0,
     40.0, 42.0, 43.0, 43.0, 43.5, 44.0]
     )
perch_weight = np.array(
    [5.9, 32.0, 40.0, 51.5, 70.0, 100.0, 78.0, 80.0, 85.0, 85.0,
     110.0, 115.0, 125.0, 130.0, 120.0, 120.0, 130.0, 135.0, 110.0,
     130.0, 150.0, 145.0, 150.0, 170.0, 225.0, 145.0, 188.0, 180.0,
     197.0, 218.0, 300.0, 260.0, 265.0, 250.0, 250.0, 300.0, 320.0,
     514.0, 556.0, 840.0, 685.0, 700.0, 700.0, 690.0, 900.0, 650.0,
     820.0, 850.0, 900.0, 1015.0, 820.0, 1100.0, 1000.0, 1100.0,
     1000.0, 1000.0]
     )

# %%
X_train,X_test,y_train,y_test = train_test_split(
    perch_length,perch_weight,random_state=42
)

# %%
X_train = X_train.reshape(-1,1)
X_test = X_test.reshape(-1,1)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (42, 1) (42,)
# (14, 1) (14,)

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train,y_train)
# Out:
# c:\Study\05python\02code\01test\Lib\site-packages\sklearn\neighbors\_base.py:501: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   check_classification_targets(y)
# KNeighborsClassifier(n_neighbors=3)

# %%
print(knn.predict([[50]]))
# Out:
# [1000.]

# %%
distansce, indexes = knn.kneighbors([[50]])

# %%
plt.scatter(X_train,y_train)
plt.scatter(X_train[indexes],y_train[indexes],marker='o')
plt.scatter(50,1033,marker='^')
plt.show()

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict([[50]])
# Out:
# array([1241.83860323])

# %%
print(lr.coef_,lr.intercept_)
# 기울기, 절편
# Out:
# [39.01714496] -709.0186449535474

# %%
# 회귀선 범위 설정
X_line = np.array([15, 50])  # 시작~끝 x값
y_line = X_line * lr.coef_[0] + lr.intercept_ 

plt.scatter(X_train,y_train)
plt.plot(X_line,y_line)
plt.scatter(10,1241,marker='^')
plt.show()

# %%
print(lr.score(X_train,y_train))
print(lr.score(X_test,y_test))
# Out:
# 0.9398463339976041
# 0.824750312331356

# %%
# 2차항 + 1차항 합치기
train_poly = np.column_stack((X_train**2, X_train))
test_poly = np.column_stack((X_test**2, X_test))

# %%
print(train_poly.shape)
print(test_poly.shape)
# Out:
# (42, 2)
# (14, 2)

# %%
train_poly
# Out:
# array([[ 384.16,   19.6 ],
#        [ 484.  ,   22.  ],
#        [ 349.69,   18.7 ],
#        [ 302.76,   17.4 ],
#        [1296.  ,   36.  ],
#        [ 625.  ,   25.  ],
#        [1600.  ,   40.  ],
#        [1521.  ,   39.  ],
#        [1849.  ,   43.  ],
#        [ 484.  ,   22.  ],
#        [ 400.  ,   20.  ],
#        [ 484.  ,   22.  ],
#        [ 576.  ,   24.  ],
#        [ 756.25,   27.5 ],
#        [1849.  ,   43.  ],
#        [1600.  ,   40.  ],
#        [ 576.  ,   24.  ],
#        [ 441.  ,   21.  ],
#        [ 756.25,   27.5 ],
#        [1600.  ,   40.  ],
#        [1075.84,   32.8 ],
#        [ 702.25,   26.5 ],
#        [1332.25,   36.5 ],
#        [ 187.69,   13.7 ],
#        [ 515.29,   22.7 ],
#        [ 225.  ,   15.  ],
#        [1369.  ,   37.  ],
#        [1225.  ,   35.  ],
#        [ 823.69,   28.7 ],
#        [ 552.25,   23.5 ],
#        [1521.  ,   39.  ],
#        [ 441.  ,   21.  ],
#        [ 529.  ,   23.  ],
#        [ 484.  ,   22.  ],
#        [1936.  ,   44.  ],
#        [ 506.25,   22.5 ],
#        [ 361.  ,   19.  ],
#        [1369.  ,   37.  ],
#        [ 484.  ,   22.  ],
#        [ 655.36,   25.6 ],
#        [1764.  ,   42.  ],
#        [1190.25,   34.5 ]])

# %%
lr = LinearRegression()
lr.fit(train_poly,y_train)
# Out:
# LinearRegression()

# %%
print(lr.predict([[50**2,50]]))
# Out:
# [1573.98423528]

# %%
print(lr.coef_,lr.intercept_)
# Out:
# [  1.01433211 -21.55792498] 116.05021078278264

# %%
point = np.arange(15,50)

plt.scatter(X_train,y_train)
plt.plot(point, 1*point**2 -21*point + 116)
plt.scatter([50],[1574],marker='^')
plt.show()

# %%
print(lr.score(train_poly, y_train))
print(lr.score(test_poly, y_test))
# Out:
# 0.9706807451768623
# 0.9775935108325122
